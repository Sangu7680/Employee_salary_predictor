# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn

# %%
df=pd.read_csv("salary_prediction_data.csv")
df
# Out:
#        Education  Experience  Location Job_Title  Age  Gender         Salary
# 0    High School           8     Urban   Manager   63    Male   84620.053665
# 1            PhD          11  Suburban  Director   59    Male  142591.255894
# 2       Bachelor          28  Suburban   Manager   61  Female   97800.255404
# 3    High School          29     Rural  Director   45    Male   96834.671282
# 4            PhD          25     Urban   Analyst   26  Female  132157.786175
# ..           ...         ...       ...       ...  ...     ...            ...
# 995  High School           8  Suburban   Analyst   25  Female   64683.389864
# 996  High School          24     Urban  Engineer   30  Female   74468.205020
# 997       Master          18     Rural   Analyst   44    Male   98207.026024
# 998     Bachelor          27  Suburban  Director   31  Female  108544.922720
# 999  High School          25     Urban  Director   41  Female   71077.000066
#
# [1000 rows x 7 columns]

# %%
df.shape
# Out:
# (1000, 7)

# %%
df.columns
# Out:
# Index(['Education', 'Experience', 'Location', 'Job_Title', 'Age', 'Gender',
#        'Salary'],
#       dtype='object')

# %%
df.info()
#data is in data uniformity correctly no need toconversion of data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Education   1000 non-null   object
#  1   Experience  1000 non-null   int64
#  2   Location    1000 non-null   object
#  3   Job_Title   1000 non-null   object
#  4   Age         1000 non-null   int64
#  5   Gender      1000 non-null   object
#  6   Salary      1000 non-null   float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 54.8+ KB

# %%
df.isna().sum()
# Out:
# Education     0
# Experience    0
# Location      0
# Job_Title     0
# Age           0
# Gender        0
# Salary        0
# dtype: int64

# %% [markdown]
# DATA CLEANING

# %%
#lets clean a EDUCATION column.
len_of_unique_values=len(df["Education"].unique())
len_of_unique_values

unique_values=df["Education"].unique()
unique_values

nullvalues=df[df["Education"].isnull()]
nullvalues

# # df["Education"].isna().sum()
# Out:
# Empty DataFrame
# Columns: [Education, Experience, Location, Job_Title, Age, Gender, Salary]
# Index: []

# %%
#lets clean a Experience column.
len_of_unique_values=len(df["Experience"].unique())
len_of_unique_values

unique_values=df["Experience"].unique()
unique_values

nullvalues=df[df["Experience"].isnull()]
nullvalues
# Out:
# Empty DataFrame
# Columns: [Education, Experience, Location, Job_Title, Age, Gender, Salary]
# Index: []

# %%
#lets clean a Location column.

len_of_unique_values=len(df["Location"].unique())
len_of_unique_values

unique_values=df["Location"].unique()
unique_values

nullvalues=df[df["Location"].isnull()]
nullvalues
# Out:
# Empty DataFrame
# Columns: [Education, Experience, Location, Job_Title, Age, Gender, Salary]
# Index: []

# %%
#lets clean a Job_Title column.

len_of_unique_values=len(df["Job_Title"].unique())
len_of_unique_values

unique_values=df["Job_Title"].unique()
unique_values

nullvalues=df[df["Job_Title"].isnull()]
nullvalues
# Out:
# Empty DataFrame
# Columns: [Education, Experience, Location, Job_Title, Age, Gender, Salary]
# Index: []

# %%
#lets clean a Age column.

nullvalues=df[df["Job_Title"].isnull()]
nullvalues
# Out:
# Empty DataFrame
# Columns: [Education, Experience, Location, Job_Title, Age, Gender, Salary]
# Index: []

# %%
# lets clean a Gender column.

len_of_unique_values=len(df["Gender"].unique())
len_of_unique_values

unique_values=df["Gender"].unique()
unique_values

nullvalues=df[df["Gender"].isnull()]
nullvalues
# Out:
# Empty DataFrame
# Columns: [Education, Experience, Location, Job_Title, Age, Gender, Salary]
# Index: []

# %%
# lets clean a salary column.
nullvalues=df[df["Salary"].isnull()]
nullvalues
# Out:
# Empty DataFrame
# Columns: [Education, Experience, Location, Job_Title, Age, Gender, Salary]
# Index: []

# %% [markdown]
# Data preprocessing

# %%
df.describe()
# Out:
#         Experience          Age         Salary
# count  1000.000000  1000.000000    1000.000000
# mean     14.771000    42.377000  105558.404239
# std       8.341111    13.609412   28256.972075
# min       1.000000    20.000000   33510.510669
# 25%       7.000000    30.000000   85032.141517
# 50%      15.000000    43.000000  104314.518315
# 75%      22.000000    55.000000  126804.047524
# max      29.000000    64.000000  193016.602150

# %%
#lets drop un usefull columns which are not that much usefull
df.drop(["Gender"],axis=1,inplace=True)
df
df=df.drop(df.columns[[2]],axis=1)  #because location index=2
df
# Out:
#        Education  Experience Job_Title  Age         Salary
# 0    High School           8   Manager   63   84620.053665
# 1            PhD          11  Director   59  142591.255894
# 2       Bachelor          28   Manager   61   97800.255404
# 3    High School          29  Director   45   96834.671282
# 4            PhD          25   Analyst   26  132157.786175
# ..           ...         ...       ...  ...            ...
# 995  High School           8   Analyst   25   64683.389864
# 996  High School          24  Engineer   30   74468.205020
# 997       Master          18   Analyst   44   98207.026024
# 998     Bachelor          27  Director   31  108544.922720
# 999  High School          25  Director   41   71077.000066
#
# [1000 rows x 5 columns]

# %%
df.describe()
df.info()
df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Education   1000 non-null   object
#  1   Experience  1000 non-null   int64
#  2   Job_Title   1000 non-null   object
#  3   Age         1000 non-null   int64
#  4   Salary      1000 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 39.2+ KB
# Index(['Education', 'Experience', 'Job_Title', 'Age', 'Salary'], dtype='object')

# %%
#Data visualization

plt.figure(figsize=(30,5))
plt.xlabel("Experience")
plt.ylabel("salary")
plt.title("SALARY INCREAMENT ACCORDING TO EXPERIENCE")

plt.bar(df["Experience"],df["Salary"]);

#we didnt find correct visualization on increament by experience

# %%
plt.figure(figsize=(30,5))
plt.xlabel("Experience")
plt.ylabel("salary")
plt.title("SALARY INCREAMENT ACCORDING TO EXPERIENCE")

plt.bar(df["Education"],df["Salary"]);

#we found that salary is more depend on the Education more then the expeerience

# %%
plt.figure(figsize=(30,5))
plt.xlabel("Experience")
plt.ylabel("salary")
plt.title("SALARY INCREAMENT ACCORDING TO EXPERIENCE")

plt.bar(df["Job_Title"],df["Salary"]);

#director job role have the highest salary then the other job roles

# %%
plt.figure(figsize=(30,5))
plt.xlabel("Age")
plt.ylabel("salary")
plt.title("SALARY INCREAMENT ACCORDING TO EXPERIENCE")

plt.bar(df["Age"],df["Salary"]);

#salaary is not predictable that much by age

# %% [markdown]
# Data preprocessing according to our needs to create a model after seeing visualization.

# %%
df["Education"].dtype
df["Job_Title"].dtype

# salary is more clear analysing through Education and job_title so these both the values dtype object(string) so we convert them to numeric
# by map fctn or one hot encoding
#because the further training and testing go through a numerical data it dont accept categeorical data..



# df['Job_Title'].unique()
# df['Education']=df['Education'].map({"High School":0,"PhD":1,"Bachelor":2,"Master":3})
# df["Job_Title"]=df["Job_Title"].map({'Manager':0, 'Director':1, 'Analyst':2, 'Engineer':3})

# df
# Out:
# dtype('O')

# %%
df=pd.get_dummies(df,columns=["Education","Job_Title"]).astype(int)
df
# Out:
#      Experience  Age  Salary  Education_Bachelor  Education_High School  \
# 0             8   63   84620                   0                      1
# 1            11   59  142591                   0                      0
# 2            28   61   97800                   1                      0
# 3            29   45   96834                   0                      1
# 4            25   26  132157                   0                      0
# ..          ...  ...     ...                 ...                    ...
# 995           8   25   64683                   0                      1
# 996          24   30   74468                   0                      1
# 997          18   44   98207                   0                      0
# 998          27   31  108544                   1                      0
# 999          25   41   71077                   0                      1
#
#      Education_Master  Education_PhD  Job_Title_Analyst  Job_Title_Director  \
# 0                   0              0                  0                   0
# 1                   0              1                  0                   1
# 2                   0              0                  0                   0
# 3                   0              0                  0                   1
# 4                   0              1                  1                   0
# ..                ...            ...                ...                 ...
# 995                 0              0                  1                   0
# 996                 0              0                  0                   0
# 997                 1              0                  1                   0
# 998                 0              0                  0                   1
# 999                 0              0                  0                   1
#
#      Job_Title_Engineer  Job_Title_Manager
# 0                     0                  1
# 1                     0                  0
# 2                     0                  1
# 3                     0                  0
# 4                     0                  0
# ..                  ...                ...
# 995                   0                  0
# 996                   1                  0
# 997                   0                  0
# 998                   0                  0
# 999                   0                  0
#
# [1000 rows x 11 columns]

# %%
df.dtypes
# Out:
# Experience               int32
# Age                      int32
# Salary                   int32
# Education_Bachelor       int32
# Education_High School    int32
# Education_Master         int32
# Education_PhD            int32
# Job_Title_Analyst        int32
# Job_Title_Director       int32
# Job_Title_Engineer       int32
# Job_Title_Manager        int32
# dtype: object

# %% [markdown]
# Training and testing the model

# %%
#lets give input of multi ip variabless and output.
df

x=df.drop(["Salary"],axis=1)#always give input in double square brackets[[]] but you want to drop one column and use all means use this
                            #Written df.drop()method
y=df["Salary"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=786)
x_train
#checking the correct percentage is given to train and test splits.
# x_train
# x_test
# Out:
#      Experience  Age  Education_Bachelor  Education_High School  \
# 420          17   35                   1                      0
# 886          27   50                   0                      1
# 40            7   40                   0                      0
# 340          21   23                   0                      0
# 274          16   52                   0                      1
# ..          ...  ...                 ...                    ...
# 615          17   62                   0                      0
# 875          20   31                   0                      0
# 202          18   25                   0                      0
# 727          14   21                   1                      0
# 798           8   55                   0                      1
#
#      Education_Master  Education_PhD  Job_Title_Analyst  Job_Title_Director  \
# 420                 0              0                  1                   0
# 886                 0              0                  0                   0
# 40                  1              0                  0                   1
# 340                 1              0                  0                   1
# 274                 0              0                  0                   0
# ..                ...            ...                ...                 ...
# 615                 1              0                  0                   1
# 875                 0              1                  0                   0
# 202                 0              1                  1                   0
# 727                 0              0                  1                   0
# 798                 0              0                  0                   0
#
#      Job_Title_Engineer  Job_Title_Manager
# 420                   0                  0
# 886                   1                  0
# 40                    0                  0
# 340                   0                  0
# 274                   0                  1
# ..                  ...                ...
# 615                   0                  0
# 875                   0                  1
# 202                   0                  0
# 727                   0                  0
# 798                   0                  1
#
# [800 rows x 10 columns]

# %%
#lets train model by a linear regression multi variables

model=LinearRegression()

# %%
#training the model

model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(x_test,y_test)
# Out:
# 0.8759421129986579

# %%
x.columns
# Out:
# Index(['Experience', 'Age', 'Education_Bachelor', 'Education_High School',
#        'Education_Master', 'Education_PhD', 'Job_Title_Analyst',
#        'Job_Title_Director', 'Job_Title_Engineer', 'Job_Title_Manager'],
#       dtype='object')

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [ 1.05293979e+03 -1.56370311e+01 -1.10932049e+04 -2.87677098e+04
#   1.05890470e+04  2.92718676e+04 -1.14480400e+04  1.37425616e+04
#  -6.41500142e+03  4.12047977e+03]
# 90518.15546018808

# %%
y_prediction=model.predict(x)

# %%
# model.predict([[5,45,1,0,0,0,0,0,1,0]]) #Example: 5 years of experience ,45 age,.. provide according to index of input data
#                                         #which is given in the X as input firstly


prediction=model.predict([[5,45,1,0,0,0,0,0,1,0]])  

print(f"{prediction[0]}")
# Out:
# 77570.98171741274
# c:\Users\sanga\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Finally saving the model to load for further use

# %%
import pickle

# After training your model
with open('salary_model.pkl', 'wb') as file:
    pickle.dump(model, file)

# %%
# When you want to use the model later
with open('salary_model.pkl', 'rb') as file:
    loaded_model = pickle.load(file)

# %%
# Manually create new input data in the form of a DataFrame
new_data = pd.DataFrame({
    'Experience': [5],  # Example: 5 years of experience
    "Age":[45],
    'Education_Bachelor': [1],  # Education level encoded
    "Education_High School":[0],
    'Education_Master': [0],
    'Education_PhD': [0],
    'Job_Title_Analyst': [0],
    'Job_Title_Director': [0],
    'Job_Title_Engineer': [1],
    'Job_Title_Manager': [0],  # Job title encoded
    # Add other required features based on how the model was trained
})

# Make predictions
predictions = loaded_model.predict(new_data)

# Show the predicted salary
print(f'Predicted Salary: {predictions}')
# Out:
# Predicted Salary: [77570.98171741]
